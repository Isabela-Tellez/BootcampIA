# %%
import pandas as pd
from io import StringIO

# %%
csv_data = """
nombre,edad,ciudad
Ana,28,Madrid
Luis,34,Barcelona
Marta,22,Valencia
"""

df = pd.read_csv(StringIO(csv_data))
df
# Out:
#   nombre  edad     ciudad
# 0    Ana    28     Madrid
# 1   Luis    34  Barcelona
# 2  Marta    22   Valencia

# %%
texto_no_estructurado = """
Ana vive en Madrid y trabaja como ingeniera.
Luis es de Barcelona y le gusta el ciclismo.
Marta estudia en Valencia y toca el piano.
"""

print(texto_no_estructurado)
# Out:
# Ana vive en Madrid y trabaja como ingeniera.
# Luis es de Barcelona y le gusta el ciclismo.
# Marta estudia en Valencia y toca el piano.
